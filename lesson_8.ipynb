# %% [markdown]
# #### Что делать
#
# Построить 5 графиков по выбранным данным.
#
# Графики должны быть различных видов и использовать хотя бы 2 из рассмотренных на занятии библиотек.
#
# Для каждого описать, какого типа переменные участвуют в визуализации, какова её цель (например, посмотреть на корреляцию двух величин или на распределение значений) и почему выбрали именно такой тип графика.
#
#
#
# #### Откуда брать данные
#
# Можно взять свой датасет или воспользоваться одним из приведенных ниже:
#
#  - Данные IMDB; https://www.kaggle.com/tmdb/tmdb-movie-metadata
#  - Данные NYC; https://www.kaggle.com/c/nyc-taxi-trip-duration
#  - Данные NBA; https://www.kaggle.com/drgilermo/nba-players-stats

# %%
# Датасет https://www.kaggle.com/tmdb/tmdb-movie-metadata#tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tmdb_5000_movies.csv')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# **budget** - бюджет фильма
#
# **genres** - жанры фильма
#
# **homepage** - страница фильма
#
# **keywords** - ключевые слова фильма
#
# **original_language** - оригинальный язык фильма
#
# **original_title** - оригинальное название фильма
#
# **overview** - описание фильма
#
# **popularity** - популярность
#
# **production_companies** - компания производитель
#
# **production_countries** - страна производитель
#
# **release_date** - дата выхода фильма
#
# **revenue** - доход фильма
#
# **runtime** - количество дней съемки?
#
# **spoken_languages** - разговорыйе языки
#
# **status** - статус
#
# **tagline** - подзаголовок
#
# **title** - название
#
# **vote_average** - средняя оценка
#
# **vote_count** - количество голосов

# %% [markdown]
# Добавим дополнительную колонку - год

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year

# %% [markdown]
# #### график 1
# Построим столбчатую диаграмму распределения 15 самых дорогих фильмов исходя из бюджета

# %%
budget_max = df.sort_values('budget', ascending=False).head(15)
plt.barh(budget_max['title'], budget_max['budget'])
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# #### график 2
# Посмотрим на круговую диаграмму сравнения количества топ-10 оригинальных языков по бюджетам, кроме en

# %%
name_dynamics = df.loc[df['original_language'] != 'en']
name_dynamics = name_dynamics.groupby(['original_language']).sum().sort_values(by='budget', ascending=False).head(10)
name_dynamics.plot(kind='pie', y='budget')

# %% [markdown]
# #### график 3
# С помощью seaborn можно построить распределение, посмотрим на распределение средних оценок критиков vote_average.
# Для этого построим distplot

# %%
sns.distplot(df.vote_average);

# %% [markdown]
# #### график 4
# Проверим как доход фильма (revenue) зависит от бюджета (budget)

# %%
_ = df.plot(kind="scatter", x="budget", y="revenue")

# %% [markdown]
# #### график 5
# Проверим, всегда ли доход фильма (revenue) окупался от бюджета (budget)

# %%
df[['revenue', 'budget'] + ['year']].groupby('year').sum().plot();

# %% [markdown]
# #### график 6
# Посмотрим как данные коррелируют друг с другом

# %%
import seaborn as sbn
plt.figure(figsize = (10,6))
sbn.heatmap(df.corr(), annot = True) 
plt.show()
